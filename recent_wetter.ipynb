# %% [markdown]
# ## DWD Wetterstation: Recent Data
#
# Wetterstation Kiel Holtenau: 02564

# %%
import requests
import zipfile
import io
import pandas as pd

# Dictionary to store each DataFrame with a unique name based on the file name
dataframes = {}

# URL of the data source
url = "https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/subdaily/air_temperature/recent/terminwerte_TU_02564_akt.zip"

# Download and extract the ZIP file
response = requests.get(url)
if response.status_code == 200:
    with zipfile.ZipFile(io.BytesIO(response.content)) as z:
        # Iterate over files in the ZIP archive
        for file_name in z.namelist():
            if file_name.endswith(".txt"):
                with z.open(file_name) as file:
                    # Read the CSV into a DataFrame and store it in the dictionary
                    df = pd.read_csv(file, sep=';', encoding='ISO-8859-1')
                    dataframes[file_name] = df  # Use file name as key
                    print(f"Data from {file_name}:")
                    print(df.head())  # Display first few rows of the DataFrame
else:
    print(f"Fehler beim Herunterladen der Daten: {response.status_code}")
# Out:
# Data from Metadaten_Stationsname_Betreibername_02564.txt:
#    Stations_ID   Stationsname  Von_Datum  Bis_Datum
# 0         2564  Kiel-Holtenau   19270201        NaN
# 1  Stations_ID  Betreibername  Von_Datum  Bis_Datum
# 2         2564   Wetterdienst   19270201   19510116
# 3         2564    GeophysBdBw   19510117   20021231
# 4         2564     GeoInfoDBw   20030101   20121231
# Data from Metadaten_Parameter_tu_termin_02564.txt:
#                Stations_ID               Von_Datum   Bis_Datum   Stationsname  \
# 0                     2564                19860601  20010331.0  Kiel-Holtenau
# 1                     2564                20010401  20241027.0  Kiel-Holtenau
# 2                     2564                19860601  20010331.0  Kiel-Holtenau
# 3                     2564                20010401  20241027.0  Kiel-Holtenau
# 4  Legende: FT  = Folgetag   GZ = Gesetzliche Zeit         NaN            NaN
#
#   Parameter              Parameterbeschreibung Einheit  \
# 0    RF_TER  Terminwerte der relativen Feuchte       %
# 1    RF_TER  Terminwerte der relativen Feuchte       %
# 2    TT_TER     Terminwerte der Lufttemperatur      °C
# 3    TT_TER     Terminwerte der Lufttemperatur      °C
# 4       NaN                                NaN     NaN
#
#                     Datenquelle (Strukturversion=SV)         Zusatz-Info  \
# 0  Klimadaten aus Klimaroutine des DWD (3 Termine...  Terminwerte in MEZ
# 1  Klimadaten aus der Klimaroutine nach 1.4.2001,...  Terminwerte in UTC
# 2  Klimadaten aus Klimaroutine des DWD (3 Termine...  Terminwerte in MEZ
# 3  Klimadaten aus der Klimaroutine nach 1.4.2001,...  Terminwerte in UTC
# 4                                                NaN                 NaN
#
#    Besonderheiten  Literaturhinweis  eor  Unnamed: 12
# 0             NaN               NaN  eor          NaN
# 1             NaN               NaN  eor          NaN
# 2             NaN               NaN  eor          NaN
# 3             NaN               NaN  eor          NaN
# 4             NaN               NaN  NaN          NaN
# Data from Metadaten_Geraete_Lufttemperatur_02564.txt:
#                                          Stations_ID   Stationsname  \
# 0                                               2564  Kiel-Holtenau
# 1                                               2564  Kiel-Holtenau
# 2  generiert: 28.10.2024 --  Deutscher Wetterdien...            NaN
#
#    Geo. Laenge [Grad]  Geo. Breite [Grad]  Stationshoehe [m]  \
# 0               10.14               54.38              27.00
# 1               10.14               54.38              28.41
# 2                 NaN                 NaN                NaN
#
#    Geberhoehe ueber Grund [m]   Von_Datum   Bis_Datum Geraetetyp Name  \
# 0                         2.0  20130501.0  20190917.0   PT 100 (Luft)
# 1                         2.0  20190918.0  20241027.0   PT 100 (Luft)
# 2                         NaN         NaN         NaN             NaN
#
#                 Messverfahren  eor  Unnamed: 11
# 0  Temperaturmessung, elektr.  eor          NaN
# 1  Temperaturmessung, elektr.  eor          NaN
# 2                         NaN  NaN          NaN
# Data from Metadaten_Geraete_Rel_Feuchte_Psychrometer_02564.txt:
#   Stations_ID   Stationsname  Geo. Laenge [Grad]  Geo. Breite [Grad]  \
# 0        2564  Kiel-Holtenau               10.14               54.38
# 1        2564  Kiel-Holtenau               10.14               54.38
# 2        2564  Kiel-Holtenau               10.14               54.38
# 3        2564  Kiel-Holtenau               10.14               54.38
# 4        2564  Kiel-Holtenau               10.14               54.38
#
#    Stationshoehe [m]  Geberhoehe ueber Grund [m]   Von_Datum   Bis_Datum  \
# 0              27.00                         2.0  19860601.0  20091231.0
# 1              27.00                         2.0  20091118.0  20130225.0
# 2              27.00                         2.0  20130501.0  20140709.0
# 3              27.00                         2.0  20140710.0  20190917.0
# 4              28.41                         2.0  20190918.0  20241027.0
#
#                Geraetetyp Name                Messverfahren  eor  Unnamed: 11
# 0  Hygrograph nach Frankenberg  Feuchteregistrierung, konv.  eor          NaN
# 1          Feuchtesonde HMP45D      Feuchtemessung, elektr.  eor          NaN
# 2          Feuchtesonde HMP45D      Feuchtemessung, elektr.  eor          NaN
# 3                         EE33      Feuchtemessung, elektr.  eor          NaN
# 4                         EE33      Feuchtemessung, elektr.  eor          NaN
# Data from Metadaten_Geographie_02564.txt:
#    Stations_id  Stationshoehe  Geogr.Breite  Geogr.Laenge  von_datum  \
# 0         2564            4.0       54.3767       10.1601   19270201
# 1         2564           26.0       54.3766       10.1485   19350401
# 2         2564            6.0       54.3696       10.1522   19460808
# 3         2564           27.0       54.3773       10.1469   19680101
# 4         2564           27.0       54.3761       10.1434   19850901
#
#   bis_datum   Stationsname
# 0  19350331  Kiel-Holtenau
# 1  19460807  Kiel-Holtenau
# 2  19671231  Kiel-Holtenau
# 3  19850831  Kiel-Holtenau
# 4  19860531  Kiel-Holtenau
# Data from produkt_tu_termin_20230427_20241027_02564.txt:
#    STATIONS_ID  MESS_DATUM  QN_4  TT_TER  RF_TER  eor
# 0         2564  2023042706     9     3.2    88.0  eor
# 1         2564  2023042712     9     9.2    59.0  eor
# 2         2564  2023042718     9     7.0    70.0  eor
# 3         2564  2023042806     9     5.8    81.0  eor
# 4         2564  2023042812     9    12.9    45.0  eor

# %%
def preprocess_data(df):
    # 1. Format der MESS_DATUM-Spalte anpassen
    df['MESS_DATUM'] = pd.to_datetime(df['MESS_DATUM'], format='%Y%m%d%H')

    # 2. Setze MESS_DATUM als Index, um die Interpolation zu erleichtern
    df.set_index('MESS_DATUM', inplace=True)
    
    # 3. Resample auf stündliche Intervalle und Interpolation
    df = df.resample('H').interpolate(method='linear')

    # 4. Reset Index, um MESS_DATUM wieder als Spalte zu haben
    df.reset_index(inplace=True)

    df.drop(['eor', 'QN_4', 'STATIONS_ID'], inplace=True, axis=1)
    df.rename(columns={'TT_TER':'Temperature',
                       'RF_TER':'Humidity',
                       'MESS_DATUM':'Timestamp'}, inplace=True)
    
    # Get the last row's data
    last_row = df.iloc[-1]

    # Create a list to store the new rows
    new_rows = []

    # Add 6 new rows with incremented timestamps
    for i in range(1, 7):
        new_row = last_row.copy()
        new_row['Timestamp'] = new_row['Timestamp'] + pd.Timedelta(hours=i)
        new_rows.append(new_row)

    # Append new rows to the DataFrame
    df = pd.concat([df, pd.DataFrame(new_rows)], ignore_index=True)


    return df

preprocess_data(df)
# Out:
# /var/folders/q2/4b4lyr6d0b320kbxlhgj_9z00000gn/T/ipykernel_4227/490605808.py:9: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df = df.resample('H').interpolate(method='linear')
# /var/folders/q2/4b4lyr6d0b320kbxlhgj_9z00000gn/T/ipykernel_4227/490605808.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df = df.resample('H').interpolate(method='linear')
#                 Timestamp  Temperature   Humidity
# 0     2023-04-27 06:00:00          3.2  88.000000
# 1     2023-04-27 07:00:00          4.2  83.166667
# 2     2023-04-27 08:00:00          5.2  78.333333
# 3     2023-04-27 09:00:00          6.2  73.500000
# 4     2023-04-27 10:00:00          7.2  68.666667
# ...                   ...          ...        ...
# 13190 2024-10-27 20:00:00          9.4  87.000000
# 13191 2024-10-27 21:00:00          9.4  87.000000
# 13192 2024-10-27 22:00:00          9.4  87.000000
# 13193 2024-10-27 23:00:00          9.4  87.000000
# 13194 2024-10-28 00:00:00          9.4  87.000000
#
# [13195 rows x 3 columns]
